# %%
pip install qiskit==0.25.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting qiskit==0.25.0
#   Downloading qiskit-0.25.0.tar.gz (4.5 kB)
#   Preparing metadata (setup.py) ... done
# Collecting qiskit-terra==0.17.0
#   Downloading qiskit_terra-0.17.0-cp39-cp39-manylinux2010_x86_64.whl (6.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 5.1 MB/s eta 0:00:00
# Collecting qiskit-aer==0.8.0
#   Downloading qiskit_aer-0.8.0-cp39-cp39-manylinux2010_x86_64.whl (17.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.9/17.9 MB 4.0 MB/s eta 0:00:00
# Collecting qiskit-ibmq-provider==0.12.2
#   Downloading qiskit_ibmq_provider-0.12.2-py3-none-any.whl (198 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.5/198.5 kB 9.7 MB/s eta 0:00:00
# Collecting qiskit-ignis==0.6.0
#   Downloading qiskit_ignis-0.6.0-py3-none-any.whl (207 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.0/207.0 kB 4.5 MB/s eta 0:00:00
# Collecting qiskit-aqua==0.9.0
#   Downloading qiskit_aqua-0.9.0-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 10.5 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.9/dist-packages (from qiskit-aer==0.8.0->qiskit==0.25.0) (1.10.1)
# Collecting pybind11>=2.6
#   Downloading pybind11-2.10.4-py3-none-any.whl (222 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.3/222.3 kB 11.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.16.3 in /usr/local/lib/python3.9/dist-packages (from qiskit-aer==0.8.0->qiskit==0.25.0) (1.22.4)
# Collecting dlx<=1.0.4
#   Downloading dlx-1.0.4.tar.gz (5.5 kB)
#   Preparing metadata (setup.py) ... done
# Collecting fastdtw<=0.3.4
#   Downloading fastdtw-0.3.4.tar.gz (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 14.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting psutil<=5.8.0,>=5
#   Downloading psutil-5.8.0-cp39-cp39-manylinux2010_x86_64.whl (293 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.5/293.5 kB 30.5 MB/s eta 0:00:00
# Requirement already satisfied: setuptools>=40.1.0 in /usr/local/lib/python3.9/dist-packages (from qiskit-aqua==0.9.0->qiskit==0.25.0) (67.6.1)
# Collecting h5py<=3.1.0
#   Downloading h5py-3.1.0-cp39-cp39-manylinux1_x86_64.whl (4.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 82.6 MB/s eta 0:00:00
# Collecting yfinance<=0.1.55
#   Downloading yfinance-0.1.55.tar.gz (23 kB)
#   Preparing metadata (setup.py) ... done
# Collecting docplex<=2.20.204
#   Downloading docplex-2.20.204.tar.gz (611 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.1/611.1 kB 46.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting retworkx<=0.8.0,>=0.7.0
#   Downloading retworkx-0.8.0-cp39-cp39-manylinux2010_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 61.7 MB/s eta 0:00:00
# Collecting scipy>=1.0
#   Downloading scipy-1.6.1-cp39-cp39-manylinux1_x86_64.whl (27.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.3/27.3 MB 72.3 MB/s eta 0:00:00
# Collecting numpy>=1.16.3
#   Downloading numpy-1.20.1-cp39-cp39-manylinux2010_x86_64.whl (15.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.4/15.4 MB 97.8 MB/s eta 0:00:00
# Collecting pandas<=1.2.3
#   Downloading pandas-1.2.3-cp39-cp39-manylinux1_x86_64.whl (9.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 98.8 MB/s eta 0:00:00
# Collecting scikit-learn<=0.24.1,>=0.20.0
#   Downloading scikit_learn-0.24.1-cp39-cp39-manylinux2010_x86_64.whl (23.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 18.1 MB/s eta 0:00:00
# Collecting quandl<=3.6.0
#   Downloading Quandl-3.6.0-py2.py3-none-any.whl (26 kB)
# Collecting sympy<=1.7.1,>=1.3
#   Downloading sympy-1.7.1-py3-none-any.whl (5.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 114.9 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.9/dist-packages (from qiskit-ibmq-provider==0.12.2->qiskit==0.25.0) (2.8.2)
# Requirement already satisfied: requests>=2.19 in /usr/local/lib/python3.9/dist-packages (from qiskit-ibmq-provider==0.12.2->qiskit==0.25.0) (2.27.1)
# Collecting requests-ntlm>=1.1.0
#   Downloading requests_ntlm-1.2.0-py3-none-any.whl (6.0 kB)
# Requirement already satisfied: urllib3>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from qiskit-ibmq-provider==0.12.2->qiskit==0.25.0) (1.26.15)
# Collecting websockets>=8
#   Downloading websockets-11.0.1-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.5/129.5 kB 14.5 MB/s eta 0:00:00
# Requirement already satisfied: nest-asyncio!=1.1.0,>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from qiskit-ibmq-provider==0.12.2->qiskit==0.25.0) (1.5.6)
# Collecting ply>=3.10
#   Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 5.7 MB/s eta 0:00:00
# Collecting dill>=0.3
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 11.5 MB/s eta 0:00:00
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.9/dist-packages (from qiskit-terra==0.17.0->qiskit==0.25.0) (4.3.3)
# Collecting python-constraint>=1.4
#   Downloading python-constraint-1.4.0.tar.bz2 (18 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: fastjsonschema>=2.10 in /usr/local/lib/python3.9/dist-packages (from qiskit-terra==0.17.0->qiskit==0.25.0) (2.16.3)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from docplex<=2.20.204->qiskit-aqua==0.9.0->qiskit==0.25.0) (1.16.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=2.6->qiskit-terra==0.17.0->qiskit==0.25.0) (0.19.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=2.6->qiskit-terra==0.17.0->qiskit==0.25.0) (22.2.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.9/dist-packages (from pandas<=1.2.3->qiskit-aqua==0.9.0->qiskit==0.25.0) (2022.7.1)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.9/dist-packages (from quandl<=3.6.0->qiskit-aqua==0.9.0->qiskit==0.25.0) (9.1.0)
# Collecting inflection>=0.3.1
#   Downloading inflection-0.5.1-py2.py3-none-any.whl (9.5 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19->qiskit-ibmq-provider==0.12.2->qiskit==0.25.0) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19->qiskit-ibmq-provider==0.12.2->qiskit==0.25.0) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19->qiskit-ibmq-provider==0.12.2->qiskit==0.25.0) (3.4)
# Requirement already satisfied: cryptography>=1.3 in /usr/local/lib/python3.9/dist-packages (from requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.12.2->qiskit==0.25.0) (40.0.1)
# Collecting pyspnego>=0.1.6
#   Downloading pyspnego-0.8.0-py3-none-any.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.7/130.7 kB 16.9 MB/s eta 0:00:00
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.9/dist-packages (from scikit-learn<=0.24.1,>=0.20.0->qiskit-aqua==0.9.0->qiskit==0.25.0) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn<=0.24.1,>=0.20.0->qiskit-aqua==0.9.0->qiskit==0.25.0) (3.1.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy<=1.7.1,>=1.3->qiskit-aqua==0.9.0->qiskit==0.25.0) (1.3.0)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.9/dist-packages (from yfinance<=0.1.55->qiskit-aqua==0.9.0->qiskit==0.25.0) (0.0.11)
# Requirement already satisfied: lxml>=4.5.1 in /usr/local/lib/python3.9/dist-packages (from yfinance<=0.1.55->qiskit-aqua==0.9.0->qiskit==0.25.0) (4.9.2)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.9/dist-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.12.2->qiskit==0.25.0) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/dist-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.12.2->qiskit==0.25.0) (2.21)
# Building wheels for collected packages: qiskit, dlx, docplex, fastdtw, python-constraint, yfinance
#   Building wheel for qiskit (setup.py) ... done
#   Created wheel for qiskit: filename=qiskit-0.25.0-py3-none-any.whl size=3027 sha256=3d2474bdcf16ba7b94a61f4543b08e0865aea485aa8aba57de26e32740e74a1d
#   Stored in directory: /root/.cache/pip/wheels/b7/e2/95/8f7d09a154a572276bcba9e15efb8dae79bca9fe21a2b7da8b
#   Building wheel for dlx (setup.py) ... done
#   Created wheel for dlx: filename=dlx-1.0.4-py3-none-any.whl size=5719 sha256=f4ea04c7eb6600758e87a50c83890ce5cfcf71579a5f869dd1656769aa7d84e5
#   Stored in directory: /root/.cache/pip/wheels/81/bd/ba/2896ffc1856e28914fcbf4d0ded1bfbb5924dad98c80ba2d5c
#   Building wheel for docplex (setup.py) ... done
#   Created wheel for docplex: filename=docplex-2.20.204-py3-none-any.whl size=675397 sha256=107b0f962890b740cb20ba8fd5fdc4fed6d938708ae19c9c28d4fc94aa585557
#   Stored in directory: /root/.cache/pip/wheels/cc/45/2c/7a3ade340351c1fa50eba8c8ca1fae091b1eba89c043a7d427
#   Building wheel for fastdtw (setup.py) ... done
#   Created wheel for fastdtw: filename=fastdtw-0.3.4-cp39-cp39-linux_x86_64.whl size=534329 sha256=a0c4af881520c45c5dec7562005e2e6e6b92e87ee323b4e685de147d1c448ed3
#   Stored in directory: /root/.cache/pip/wheels/1f/a1/63/bfd0fddb5bf0b59f564872e29272cee8a2de0cd745d88fede5
#   Building wheel for python-constraint (setup.py) ... done
#   Created wheel for python-constraint: filename=python_constraint-1.4.0-py2.py3-none-any.whl size=24082 sha256=08a04306b538a744f59c889d566acd487eed3226f4adabf908c4a75816ed1374
#   Stored in directory: /root/.cache/pip/wheels/51/36/1f/c2ccb8dc4eba38c5215636d4ae2c480b32069cab0376bcc1a4
#   Building wheel for yfinance (setup.py) ... done
#   Created wheel for yfinance: filename=yfinance-0.1.55-py2.py3-none-any.whl size=22628 sha256=45778638e48360dcf9be5910baa62686fa7f1bf7cbe00c3eeb83e4a2dd536346
#   Stored in directory: /root/.cache/pip/wheels/75/6f/b1/2a6be95ab6a39ae5e82cef79a5bed8b5b841ee1322fecf3dee
# Successfully built qiskit dlx docplex fastdtw python-constraint yfinance
# Installing collected packages: python-constraint, ply, dlx, websockets, sympy, pybind11, psutil, numpy, inflection, dill, scipy, retworkx, pandas, h5py, fastdtw, docplex, yfinance, scikit-learn, quandl, qiskit-terra, pyspnego, requests-ntlm, qiskit-ignis, qiskit-aer, qiskit-ibmq-provider, qiskit-aqua, qiskit
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.11.1
#     Uninstalling sympy-1.11.1:
#       Successfully uninstalled sympy-1.11.1
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.9.4
#     Uninstalling psutil-5.9.4:
#       Successfully uninstalled psutil-5.9.4
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.4
#     Uninstalling numpy-1.22.4:
#       Successfully uninstalled numpy-1.22.4
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.10.1
#     Uninstalling scipy-1.10.1:
#       Successfully uninstalled scipy-1.10.1
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.8.0
#     Uninstalling h5py-3.8.0:
#       Successfully uninstalled h5py-3.8.0
#   Attempting uninstall: yfinance
#     Found existing installation: yfinance 0.2.17
#     Uninstalling yfinance-0.2.17:
#       Successfully uninstalled yfinance-0.2.17
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yellowbrick 1.5 requires scikit-learn>=1.0.0, but you have scikit-learn 0.24.1 which is incompatible.
# xarray 2022.12.0 requires pandas>=1.3, but you have pandas 1.2.3 which is incompatible.
# tensorflow 2.12.0 requires numpy<1.24,>=1.22, but you have numpy 1.20.1 which is incompatible.
# plotnine 0.10.1 requires pandas>=1.3.5, but you have pandas 1.2.3 which is incompatible.
# mizani 0.8.1 requires pandas>=1.3.5, but you have pandas 1.2.3 which is incompatible.
# librosa 0.10.0.post2 requires numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3, but you have numpy 1.20.1 which is incompatible.
# jaxlib 0.4.7+cuda11.cudnn86 requires numpy>=1.21, but you have numpy 1.20.1 which is incompatible.
# jaxlib 0.4.7+cuda11.cudnn86 requires scipy>=1.7, but you have scipy 1.6.1 which is incompatible.
# jax 0.4.8 requires numpy>=1.21, but you have numpy 1.20.1 which is incompatible.
# jax 0.4.8 requires scipy>=1.7, but you have scipy 1.6.1 which is incompatible.
# imbalanced-learn 0.10.1 requires scikit-learn>=1.0.2, but you have scikit-learn 0.24.1 which is incompatible.
# google-colab 1.0.0 requires pandas~=1.5.3, but you have pandas 1.2.3 which is incompatible.
# gensim 4.3.1 requires scipy>=1.7.0, but you have scipy 1.6.1 which is incompatible.
# cmdstanpy 1.1.0 requires numpy>=1.21, but you have numpy 1.20.1 which is incompatible.
# arviz 0.15.1 requires pandas>=1.3.0, but you have pandas 1.2.3 which is incompatible.
# arviz 0.15.1 requires scipy>=1.8.0, but you have scipy 1.6.1 which is incompatible.
# Successfully installed dill-0.3.6 dlx-1.0.4 docplex-2.20.204 fastdtw-0.3.4 h5py-3.1.0 inflection-0.5.1 numpy-1.20.1 pandas-1.2.3 ply-3.11 psutil-5.8.0 pybind11-2.10.4 pyspnego-0.8.0 python-constraint-1.4.0 qiskit-0.25.0 qiskit-aer-0.8.0 qiskit-aqua-0.9.0 qiskit-ibmq-provider-0.12.2 qiskit-ignis-0.6.0 qiskit-terra-0.17.0 quandl-3.6.0 requests-ntlm-1.2.0 retworkx-0.8.0 scikit-learn-0.24.1 scipy-1.6.1 sympy-1.7.1 websockets-11.0.1 yfinance-0.1.55

# %%
pip install qiskit-quantum-knn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: qiskit-quantum-knn in /usr/local/lib/python3.9/dist-packages (1.0.1)
# Requirement already satisfied: qiskit in /usr/local/lib/python3.9/dist-packages (from qiskit-quantum-knn) (0.25.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from qiskit-quantum-knn) (1.20.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from qiskit-quantum-knn) (1.6.1)
# Requirement already satisfied: qiskit-aer==0.8.0 in /usr/local/lib/python3.9/dist-packages (from qiskit->qiskit-quantum-knn) (0.8.0)
# Requirement already satisfied: qiskit-ignis==0.6.0 in /usr/local/lib/python3.9/dist-packages (from qiskit->qiskit-quantum-knn) (0.6.0)
# Requirement already satisfied: qiskit-ibmq-provider==0.12.2 in /usr/local/lib/python3.9/dist-packages (from qiskit->qiskit-quantum-knn) (0.12.2)
# Requirement already satisfied: qiskit-aqua==0.9.0 in /usr/local/lib/python3.9/dist-packages (from qiskit->qiskit-quantum-knn) (0.9.0)
# Requirement already satisfied: qiskit-terra==0.17.0 in /usr/local/lib/python3.9/dist-packages (from qiskit->qiskit-quantum-knn) (0.17.0)
# Requirement already satisfied: pybind11>=2.6 in /usr/local/lib/python3.9/dist-packages (from qiskit-aer==0.8.0->qiskit->qiskit-quantum-knn) (2.10.4)
# Requirement already satisfied: yfinance<=0.1.55 in /usr/local/lib/python3.9/dist-packages (from qiskit-aqua==0.9.0->qiskit->qiskit-quantum-knn) (0.1.55)
# Requirement already satisfied: pandas<=1.2.3 in /usr/local/lib/python3.9/dist-packages (from qiskit-aqua==0.9.0->qiskit->qiskit-quantum-knn) (1.2.3)
# Requirement already satisfied: psutil<=5.8.0,>=5 in /usr/local/lib/python3.9/dist-packages (from qiskit-aqua==0.9.0->qiskit->qiskit-quantum-knn) (5.8.0)
# Requirement already satisfied: quandl<=3.6.0 in /usr/local/lib/python3.9/dist-packages (from qiskit-aqua==0.9.0->qiskit->qiskit-quantum-knn) (3.6.0)
# Requirement already satisfied: setuptools>=40.1.0 in /usr/local/lib/python3.9/dist-packages (from qiskit-aqua==0.9.0->qiskit->qiskit-quantum-knn) (67.6.1)
# Requirement already satisfied: sympy<=1.7.1,>=1.3 in /usr/local/lib/python3.9/dist-packages (from qiskit-aqua==0.9.0->qiskit->qiskit-quantum-knn) (1.7.1)
# Requirement already satisfied: scikit-learn<=0.24.1,>=0.20.0 in /usr/local/lib/python3.9/dist-packages (from qiskit-aqua==0.9.0->qiskit->qiskit-quantum-knn) (0.24.1)
# Requirement already satisfied: retworkx<=0.8.0,>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from qiskit-aqua==0.9.0->qiskit->qiskit-quantum-knn) (0.8.0)
# Requirement already satisfied: dlx<=1.0.4 in /usr/local/lib/python3.9/dist-packages (from qiskit-aqua==0.9.0->qiskit->qiskit-quantum-knn) (1.0.4)
# Requirement already satisfied: h5py<=3.1.0 in /usr/local/lib/python3.9/dist-packages (from qiskit-aqua==0.9.0->qiskit->qiskit-quantum-knn) (3.1.0)
# Requirement already satisfied: fastdtw<=0.3.4 in /usr/local/lib/python3.9/dist-packages (from qiskit-aqua==0.9.0->qiskit->qiskit-quantum-knn) (0.3.4)
# Requirement already satisfied: docplex<=2.20.204 in /usr/local/lib/python3.9/dist-packages (from qiskit-aqua==0.9.0->qiskit->qiskit-quantum-knn) (2.20.204)
# Requirement already satisfied: websockets>=8 in /usr/local/lib/python3.9/dist-packages (from qiskit-ibmq-provider==0.12.2->qiskit->qiskit-quantum-knn) (11.0.1)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.9/dist-packages (from qiskit-ibmq-provider==0.12.2->qiskit->qiskit-quantum-knn) (2.8.2)
# Requirement already satisfied: urllib3>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from qiskit-ibmq-provider==0.12.2->qiskit->qiskit-quantum-knn) (1.26.15)
# Requirement already satisfied: requests-ntlm>=1.1.0 in /usr/local/lib/python3.9/dist-packages (from qiskit-ibmq-provider==0.12.2->qiskit->qiskit-quantum-knn) (1.2.0)
# Requirement already satisfied: nest-asyncio!=1.1.0,>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from qiskit-ibmq-provider==0.12.2->qiskit->qiskit-quantum-knn) (1.5.6)
# Requirement already satisfied: requests>=2.19 in /usr/local/lib/python3.9/dist-packages (from qiskit-ibmq-provider==0.12.2->qiskit->qiskit-quantum-knn) (2.27.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.9/dist-packages (from qiskit-terra==0.17.0->qiskit->qiskit-quantum-knn) (4.3.3)
# Requirement already satisfied: fastjsonschema>=2.10 in /usr/local/lib/python3.9/dist-packages (from qiskit-terra==0.17.0->qiskit->qiskit-quantum-knn) (2.16.3)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.9/dist-packages (from qiskit-terra==0.17.0->qiskit->qiskit-quantum-knn) (0.3.6)
# Requirement already satisfied: ply>=3.10 in /usr/local/lib/python3.9/dist-packages (from qiskit-terra==0.17.0->qiskit->qiskit-quantum-knn) (3.11)
# Requirement already satisfied: python-constraint>=1.4 in /usr/local/lib/python3.9/dist-packages (from qiskit-terra==0.17.0->qiskit->qiskit-quantum-knn) (1.4.0)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from docplex<=2.20.204->qiskit-aqua==0.9.0->qiskit->qiskit-quantum-knn) (1.16.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=2.6->qiskit-terra==0.17.0->qiskit->qiskit-quantum-knn) (0.19.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=2.6->qiskit-terra==0.17.0->qiskit->qiskit-quantum-knn) (22.2.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.9/dist-packages (from pandas<=1.2.3->qiskit-aqua==0.9.0->qiskit->qiskit-quantum-knn) (2022.7.1)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.9/dist-packages (from quandl<=3.6.0->qiskit-aqua==0.9.0->qiskit->qiskit-quantum-knn) (9.1.0)
# Requirement already satisfied: inflection>=0.3.1 in /usr/local/lib/python3.9/dist-packages (from quandl<=3.6.0->qiskit-aqua==0.9.0->qiskit->qiskit-quantum-knn) (0.5.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19->qiskit-ibmq-provider==0.12.2->qiskit->qiskit-quantum-knn) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19->qiskit-ibmq-provider==0.12.2->qiskit->qiskit-quantum-knn) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19->qiskit-ibmq-provider==0.12.2->qiskit->qiskit-quantum-knn) (2.0.12)
# Requirement already satisfied: pyspnego>=0.1.6 in /usr/local/lib/python3.9/dist-packages (from requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.12.2->qiskit->qiskit-quantum-knn) (0.8.0)
# Requirement already satisfied: cryptography>=1.3 in /usr/local/lib/python3.9/dist-packages (from requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.12.2->qiskit->qiskit-quantum-knn) (40.0.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.9/dist-packages (from scikit-learn<=0.24.1,>=0.20.0->qiskit-aqua==0.9.0->qiskit->qiskit-quantum-knn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn<=0.24.1,>=0.20.0->qiskit-aqua==0.9.0->qiskit->qiskit-quantum-knn) (3.1.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy<=1.7.1,>=1.3->qiskit-aqua==0.9.0->qiskit->qiskit-quantum-knn) (1.3.0)
# Requirement already satisfied: lxml>=4.5.1 in /usr/local/lib/python3.9/dist-packages (from yfinance<=0.1.55->qiskit-aqua==0.9.0->qiskit->qiskit-quantum-knn) (4.9.2)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.9/dist-packages (from yfinance<=0.1.55->qiskit-aqua==0.9.0->qiskit->qiskit-quantum-knn) (0.0.11)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.9/dist-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.12.2->qiskit->qiskit-quantum-knn) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/dist-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.12.2->qiskit->qiskit-quantum-knn) (2.21)

# %%
import qiskit as qk
import qiskit_quantum_knn
from qiskit_quantum_knn.qknn import QKNeighborsClassifier
from qiskit_quantum_knn.encoding import analog
from qiskit import aqua
from sklearn import datasets

import pandas as pd
import numpy as np

# %%
qk.__qiskit_version__
# Out:
# {'qiskit-terra': '0.17.0', 'qiskit-aer': '0.8.0', 'qiskit-ignis': '0.6.0', 'qiskit-ibmq-provider': '0.12.2', 'qiskit-aqua': '0.9.0', 'qiskit': None}

# %% [markdown]
# #QKNN

# %%
# initialising the quantum instance
backend = qk.BasicAer.get_backend('qasm_simulator')      
instance = qk.aqua.QuantumInstance(backend, shots=100)  
                                                   
# initialising the qknn model
qknn = QKNeighborsClassifier(n_neighbors=3,quantum_instance=instance)

# %%
n_variables = 4       # should be positive power of 2
n_train_points = 20     # can be any positive integer
n_test_points = 5    # can be any positive integer

# use iris dataset
iris = datasets.load_iris()
labels = iris.target
data_raw = iris.data

# %%
len(data_raw)
# Out:
# 150

# %%
# encode data
encoded_data = analog.encode(data_raw[:, :n_variables])

# now pick these indices from the data
train_data = encoded_data[:n_train_points]
train_labels = labels[:n_train_points]

test_data = encoded_data[n_train_points:(n_train_points+n_test_points), :n_variables]
test_labels = labels[n_train_points:(n_train_points+n_test_points)]

# %%
qknn.fit(train_data, train_labels)

# %%
qknn_prediction = qknn.predict(test_data)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-53-4490a2385f4e> in <cell line: 1>()
# ----> 1 qknn_prediction = qknn.predict(test_data)
#       2
#
# /usr/local/lib/python3.9/dist-packages/qiskit_quantum_knn/qknn/qkneighborsclassifier.py in predict(self, data)
#     474     def predict(self, data) -> np.ndarray:
#     475         """Predict the labels of the provided data."""
# --> 476         return self.instance.predict(data)
#     477
#     478     def _run(self) -> Dict:
#
# /usr/local/lib/python3.9/dist-packages/qiskit_quantum_knn/qknn/_qknn.py in predict(self, data)
#      30         )
#      31
# ---> 32         predicted_labels = self._qalgo.majority_vote(
#      33             self._qalgo.training_labels,
#      34             contrasts
#
# /usr/local/lib/python3.9/dist-packages/qiskit_quantum_knn/qknn/qkneighborsclassifier.py in majority_vote(self, labels, contrasts)
#     445
#     446         # voters = np.take(data, indices_of_neighbors, axis=0)
# --> 447         voter_labels = np.take(labels, indices_of_neighbors)
#     448         if n_queries == 1:
#     449             votes, counts = stats.mode(voter_labels)
#
# /usr/local/lib/python3.9/dist-packages/numpy/core/overrides.py in take(*args, **kwargs)
#
# /usr/local/lib/python3.9/dist-packages/numpy/core/fromnumeric.py in take(a, indices, axis, out, mode)
#     188     array([[4, 3],
#     189            [5, 7]])
# --> 190     """
#     191     return _wrapfunc(a, 'take', indices, axis=axis, out=out, mode=mode)
#     192
#
# /usr/local/lib/python3.9/dist-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      55         return _wrapit(obj, method, *args, **kwds)
#      56
# ---> 57     try:
#      58         return bound(*args, **kwds)
#      59     except TypeError:
#
# IndexError: index 31 is out of bounds for axis 0 with size 20
